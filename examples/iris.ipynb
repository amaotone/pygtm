# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_iris

from pygtm import GTM

# %%
iris = load_iris()

model = make_pipeline(
    StandardScaler(),
    GTM(n_components=2, max_iter=50, tol=1e-2, verbose=True)
)

# %%
model.fit(iris.data)
# Out:
# cycle #1: likelihood: -241.781, diff: inf
# cycle #2: likelihood: -162.137, diff: 0.531
# cycle #3: likelihood: -98.588, diff: 0.424
# cycle #4: likelihood: -48.767, diff: 0.332
# cycle #5: likelihood: -8.054, diff: 0.271
# cycle #6: likelihood: 25.826, diff: 0.226
# cycle #7: likelihood: 54.760, diff: 0.193
# cycle #8: likelihood: 80.826, diff: 0.174
# cycle #9: likelihood: 105.025, diff: 0.161
# cycle #10: likelihood: 127.577, diff: 0.150
# cycle #11: likelihood: 148.470, diff: 0.139
# cycle #12: likelihood: 167.608, diff: 0.128
# cycle #13: likelihood: 184.858, diff: 0.115
# cycle #14: likelihood: 200.159, diff: 0.102
# cycle #15: likelihood: 213.623, diff: 0.090
# cycle #16: likelihood: 225.526, diff: 0.079
# cycle #17: likelihood: 236.216, diff: 0.071
# cycle #18: likelihood: 245.943, diff: 0.065
# cycle #19: likelihood: 254.683, diff: 0.058
# cycle #20: likelihood: 262.360, diff: 0.051
# cycle #21: likelihood: 269.106, diff: 0.045
# cycle #22: likelihood: 275.147, diff: 0.040
# cycle #23: likelihood: 280.686, diff: 0.037
# cycle #24: likelihood: 285.747, diff: 0.034
# cycle #25: likelihood: 290.155, diff: 0.029
# cycle #26: likelihood: 293.751, diff: 0.024
# cycle #27: likelihood: 296.536, diff: 0.019
# cycle #28: likelihood: 298.637, diff: 0.014
# cycle #29: likelihood: 300.218, diff: 0.011
# cycle #30: likelihood: 301.440, diff: 0.008
# converged.
# Pipeline(memory=None,
#      steps=[('standardscaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('gtm', GTM(alpha=0.001, max_iter=50, method='mean', n_components=2, n_grids=20,
#   n_rbfs=10, random_state=None, sigma=1, tol=0.01, verbose=True))])

# %%
Xt = model.transform(iris.data)
plt.scatter(*Xt.T, c=iris.target, cmap=plt.cm.rainbow)
plt.show()

# %%
model.named_steps.gtm.method = 'mode'
Xt = model.transform(iris.data)
plt.scatter(*Xt.T, c=iris.target, cmap=plt.cm.rainbow)
plt.show()
