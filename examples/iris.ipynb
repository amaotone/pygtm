# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_iris

from pygtm import GTM

# %%
iris = load_iris()

model = make_pipeline(
    StandardScaler(),
    GTM(n_components=2, max_iter=30, verbose=True)
)

# %%
Xt = model.fit_transform(iris.data)
# Out:
# cycle #1: -241.78116909989188
# cycle #2: -162.136570260963
# cycle #3: -98.58791733777008
# cycle #4: -48.76662839686584
# cycle #5: -8.053789925054003
# cycle #6: 25.825732145979682
# cycle #7: 54.75976733627881
# cycle #8: 80.8260863744729
# cycle #9: 105.024897497905
# cycle #10: 127.57688578481414
# cycle #11: 148.4702334383449
# cycle #12: 167.6075033790993
# cycle #13: 184.8583298957159
# cycle #14: 200.15914465378975
# cycle #15: 213.62254322783724
# cycle #16: 225.5258002071197
# cycle #17: 236.21600313915735
# cycle #18: 245.94340575653686
# cycle #19: 254.68253409620962
# cycle #20: 262.36049184903396
# cycle #21: 269.106030832141
# cycle #22: 275.14712067129335
# cycle #23: 280.686237940383
# cycle #24: 285.7467486984455
# cycle #25: 290.15496586623567
# cycle #26: 293.75104282292205
# cycle #27: 296.5363784635158
# cycle #28: 298.636771009285
# cycle #29: 300.2184951537262
# cycle #30: 301.4402126027256

# %%
plt.scatter(*Xt.T, c=iris.target, cmap=plt.cm.rainbow)
plt.show()
